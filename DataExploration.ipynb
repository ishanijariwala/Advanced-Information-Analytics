# %% [markdown]
# Importing relevant packages

# %%
import pandas as pd
import numpy as np

# %%
from pandas import DataFrame, Series

# %% [markdown]
# Loading the data set into pandas data frame

# %%
cc = pd.read_csv('UCI_Credit_Card.csv', header=None,
                  names=['CustId','Limit','Sex','Edu','Marital_Status','Age','Repay_Sep','Repay_Aug','Repay_Jul','Repay_Jun',
                        'Repay_May','Repay_Apr','Bill_Sep','Bill_Aug','Bill_Jul','Bill_Jun','Bill_May','Bill_Apr','Pay_Sep',
                        'Pay_Aug','Pay_Jul','Pay_Jun','Pay_May','Pay_Apr','Default_Nxt_Mnth'])
cc.head(5)
# Out:
#   CustId      Limit  Sex        Edu Marital_Status  Age Repay_Sep Repay_Aug  \
# 0     ID  LIMIT_BAL  SEX  EDUCATION       MARRIAGE  AGE     PAY_0     PAY_2
# 1      1      20000    2          2              1   24         2         2
# 2      2     120000    2          2              2   26        -1         2
# 3      3      90000    2          2              2   34         0         0
# 4      4      50000    2          2              1   37         0         0
#
#   Repay_Jul Repay_Jun             ...               Bill_Jun   Bill_May  \
# 0     PAY_3     PAY_4             ...              BILL_AMT4  BILL_AMT5
# 1        -1        -1             ...                      0          0
# 2         0         0             ...                   3272       3455
# 3         0         0             ...                  14331      14948
# 4         0         0             ...                  28314      28959
#
#     Bill_Apr   Pay_Sep   Pay_Aug   Pay_Jul   Pay_Jun   Pay_May   Pay_Apr  \
# ...

# %%
# %matplotlib inline
import seaborn as sns
sns.set_style("white")
import matplotlib as mpl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
cc_data = cc[cc.Sex != 'SEX']
cc_data.head(5)
# Out:
#   CustId   Limit Sex Edu Marital_Status Age Repay_Sep Repay_Aug Repay_Jul  \
# 1      1   20000   2   2              1  24         2         2        -1
# 2      2  120000   2   2              2  26        -1         2         0
# 3      3   90000   2   2              2  34         0         0         0
# 4      4   50000   2   2              1  37         0         0         0
# 5      5   50000   1   2              1  57        -1         0        -1
#
#   Repay_Jun       ...        Bill_Jun Bill_May Bill_Apr Pay_Sep Pay_Aug  \
# 1        -1       ...               0        0        0       0     689
# 2         0       ...            3272     3455     3261       0    1000
# 3         0       ...           14331    14948    15549    1518    1500
# 4         0       ...           28314    28959    29547    2000    2019
# 5         0       ...           20940    19146    19131    2000   36681
#
#   Pay_Jul Pay_Jun Pay_May Pay_Apr Default_Nxt_Mnth
# ...

# %% [markdown]
# Calculating the correlation of features with label

# %%
cc_data['Limit'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.15351987639350759
cc_data['Sex'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.03996057770544164
cc_data['Edu'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.028006077656249941
cc_data['Marital_Status'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.024339215683404289
cc_data['Age'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.013889834301963193
cc_data['Repay_Sep'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.32479372847862176
cc_data['Repay_Aug'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.26355120167216478
cc_data['Repay_Jul'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.23525251372491573
cc_data['Repay_Jun'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.21661363684242427
cc_data['Repay_May'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.20414891387616621
cc_data['Repay_Apr'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #0.18686636165354517
cc_data['Bill_Sep'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.019644197143221555
cc_data['Bill_Aug'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.014193218088215716
cc_data['Bill_Jul'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.014075518043214762
cc_data['Bill_Jun'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.010156495880289681
cc_data['Bill_May'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.0067604638410147183
cc_data['Bill_Apr'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.0053723149148155024
cc_data['Pay_Sep'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.072929487777851396
cc_data['Pay_Aug'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.058578706582900854
cc_data['Pay_Jul'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.056250350990331134
cc_data['Pay_Jun'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.056827400892887618
cc_data['Pay_May'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.055123515621088477
cc_data['Pay_Apr'].astype(float).corr(cc_data['Default_Nxt_Mnth'].astype(float)) #-0.053183340326128072
# Out:
# -0.053183340326128072

# %% [markdown]
# Converting the data columns into numeric data type

# %%
cc_data = cc_data.apply(lambda x: pd.to_numeric(x, errors='ignore'))

# %% [markdown]
# Exploring the data

# %%
plt = cc_data.plot.scatter(x='Default_Nxt_Mnth',y='Limit', marker='x', color='Red', label='Repayment Status Sep')
#plt = cc_data.plot.scatter(x='Repay_Aug',y='Default_Nxt_Mnth', marker='o', ax=plt, color='Blue', label='Repayment Status Aug')
plt.set_xlabel("Repayment Status")
plt.set_ylabel("Default Next Month")
plt

# %%
plt = cc_data.plot.scatter(x='Repay_Sep',y='Bill_Sep', marker='x', color='Red', label='Repayment Status Sep')
#plt = cc_data.plot.scatter(x='Repay_Aug',y='Default_Nxt_Mnth', marker='o', ax=plt, color='Blue', label='Repayment Status Aug')
plt.set_xlabel("Repayment Status")
plt.set_ylabel("Default Next Month")
plt

# %%
cc_data_sep = cc_data[cc_data.Bill_Sep<900000]
cc_data_sep.boxplot(column='Bill_Sep', by='Default_Nxt_Mnth', ax=None, grid=True)

# %%
cc_data[cc_data.Default_Nxt_Mnth == 0].Bill_Sep.describe()
# Out:
# count     23364.000000
# mean      51994.227273
# std       73577.606694
# min     -165580.000000
# 25%        3677.250000
# 50%       23119.500000
# 75%       69027.000000
# max      964511.000000
# Name: Bill_Sep, dtype: float64

# %%
cc_data[cc_data.Default_Nxt_Mnth == 1].Bill_Sep.describe()
# Out:
# count      6636.000000
# mean      48509.162297
# std       73782.067220
# min       -6676.000000
# 25%        2987.750000
# 50%       20185.000000
# 75%       59626.500000
# max      613860.000000
# Name: Bill_Sep, dtype: float64

# %%
cc_data[['Repay_Sep']].plot(kind='hist')

# %%
cc_data[['Repay_Aug']].plot(kind='hist')

# %%
cc_data[['Repay_Jul']].plot(kind='hist')

# %%
cc_data[['Repay_Jun']].plot(kind='hist')

# %%
cc_data[['Repay_May']].plot(kind='hist')

# %%
cc_data[['Repay_Apr']].plot(kind='hist')

# %%
plt = cc_data.plot.scatter(x='Limit',y='Repay_Sep', marker='x', color='Red', label='Repayment Status Sep')

# %%
cc_data['TotalBill'] = cc_data['Bill_Sep']+cc_data['Bill_Aug']+cc_data['Bill_Jul']+cc_data['Bill_Jun']+cc_data['Bill_May']+cc_data['Bill_Apr']
cc_data['TotalPayment'] = cc_data['Pay_Sep']+cc_data['Pay_Aug']+cc_data['Pay_Jul']+cc_data['Pay_Jun']+cc_data['Pay_May']+cc_data['Pay_Apr']
cc_data['TotalRemaining'] = cc_data['TotalBill'] - cc_data['TotalPayment']

# %%
cc_data['TotalRemaining'].corr(cc_data['Limit'].astype(float)) #0.25661573580830205
cc_data['TotalBill'].corr(cc_data['Limit'].astype(float)) #0.30204379702615852
cc_data['TotalPayment'].corr(cc_data['Limit'].astype(float)) #0.35265495357645421
# Out:
# 0.35265495357645421

# %%
plt = cc_data.plot.scatter(x='Limit',y='TotalPayment', marker='x', color='Red', label='Repayment Status Sep')

# %%
plt = cc_data.plot.scatter(x='TotalBill',y='TotalPayment', marker='x', color='Red', label='Total Bill vs Total Payment')

# %%
cc_data_pay = cc_data[cc_data.TotalPayment<500000]
cc_data['ScaledPay'] = cc_data['TotalPayment']/1000000
cc_data_pay.boxplot(column='TotalPayment', by='Default_Nxt_Mnth', ax=None, grid=True)

# %%
cc_data[cc_data.Default_Nxt_Mnth == 0].TotalPayment.describe()
# Out:
# count    2.336400e+04
# mean     3.496942e+04
# std      6.568226e+04
# min      0.000000e+00
# 25%      7.420250e+03
# 50%      1.652400e+04
# 75%      3.712900e+04
# max      3.764066e+06
# Name: TotalPayment, dtype: float64

# %%
cc_data[cc_data.Default_Nxt_Mnth == 1].TotalPayment.describe()
# Out:
# count      6636.000000
# mean      19969.293701
# std       36915.631317
# min           0.000000
# 25%        4848.500000
# 50%        9674.500000
# 75%       21300.750000
# max      704208.000000
# Name: TotalPayment, dtype: float64

# %%
cc_data.boxplot(column='TotalBill', by='Default_Nxt_Mnth', ax=None, grid=True)

# %%
cc_data[cc_data.Default_Nxt_Mnth == 0].TotalBill.describe()
# Out:
# count    2.336400e+04
# mean     2.724289e+05
# std      3.777519e+05
# min     -1.254800e+05
# 25%      3.013425e+04
# 50%      1.286605e+05
# 75%      3.501940e+05
# max      5.263883e+06
# Name: TotalBill, dtype: float64

# %%
cc_data[cc_data.Default_Nxt_Mnth == 1].TotalBill.describe()
# Out:
# count    6.636000e+03
# mean     2.608230e+05
# std      3.857705e+05
# min     -3.362590e+05
# 25%      2.275775e+04
# 50%      1.186880e+05
# 75%      3.079915e+05
# max      3.127490e+06
# Name: TotalBill, dtype: float64

# %%
cc_data[cc_data.Default_Nxt_Mnth == 0].TotalRemaining.describe()
# Out:
# count    2.336400e+04
# mean     2.374595e+05
# std      3.613816e+05
# min     -2.671514e+06
# 25%      3.965000e+03
# 50%      9.951100e+04
# 75%      3.111780e+05
# max      4.116080e+06
# Name: TotalRemaining, dtype: float64

# %%
cc_data[cc_data.Default_Nxt_Mnth == 1].TotalRemaining.describe()
# Out:
# count    6.636000e+03
# mean     2.408537e+05
# std      3.693910e+05
# min     -6.839980e+05
# 25%      7.956000e+03
# 50%      1.079120e+05
# 75%      2.898615e+05
# max      3.017490e+06
# Name: TotalRemaining, dtype: float64

# %%
cc_data.boxplot(column='TotalRemaining', by='Default_Nxt_Mnth', ax=None, grid=True)
